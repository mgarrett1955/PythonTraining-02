# %%
import pandas_datareader.data as web
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import datetime as dt

# %%
#start of the data
start = dt.datetime(2020,1,1)

# %%
#last data point to download      
end = dt.datetime(2022,1,1)

# %%
# name of the stock symbol
symbol = 'AAPL' ###using Apple as an example

# %%
##source of the data
source = 'yahoo'

# %%
# pass in the arguments above to pandas datareader
data = web.DataReader(symbol, source, start, end)

# %%
##view first 5 rows of the data
data.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  73.683571
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  72.967224
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  73.548637
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.202721
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.380287

# %%
plt.figure(figsize = (15,5))
plt.plot(data['High'])
plt.plot(data['Low'])
plt.title('Apple Stock Data')
# Out:
# Text(0.5, 1.0, 'Apple Stock Data')

# %%
import time

# %%
i = 0
while(i < 10):
    print("Check stock price, but sell or hold decision")
    i = i + 1
    time.sleep(2.0)
# Out:
# Printed immediately.
# Printed after 2.4 seconds.
# Printed immediately.
# Printed after 2.4 seconds.
# Printed immediately.
# Printed after 2.4 seconds.
# Printed immediately.
# Printed after 2.4 seconds.
# Printed immediately.
# Printed after 2.4 seconds.
# Printed immediately.
# Printed after 2.4 seconds.
# Printed immediately.
# Printed after 2.4 seconds.
# Printed immediately.
# Printed after 2.4 seconds.
# Printed immediately.
# Printed after 2.4 seconds.
# Printed immediately.
# Printed after 2.4 seconds.

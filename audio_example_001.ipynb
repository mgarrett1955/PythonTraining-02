# %%
import math as math
import numpy as np
import scipy as sp
import scipy.io as spio
import scipy.signal as signal
from scipy.signal import hilbert, chirp, periodogram
from scipy.io import wavfile
import matplotlib.pyplot as plt

# %%
import IPython.display as ipd

# %%
samplerate, data = wavfile.read('testing.wav')
# Out:
# <ipython-input-23-e2afb6540d20>:1: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   samplerate, data = wavfile.read('testing.wav')

# %%
samplerate
# Out:
# 48000

# %%
type(samplerate)
# Out:
# int

# %%
type(data)
# Out:
# numpy.ndarray

# %%
plt.figure(figsize = (15,5))
plt.plot(data)

# %%
ipd.Audio(data, rate=samplerate) # load a NumPy array
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
copy = np.copy(data)

# %%
delay_time = 0.25

# %%
delayed = np.roll(copy, int(samplerate * delay_time))

# %%
ipd.Audio(data + delayed, rate=samplerate) # load a NumPy array
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
samplerate, data_2 = wavfile.read('whistle.wav')

# %%
ipd.Audio(data_2, rate=samplerate) # load a NumPy array
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len_data = len(data)
len_data2 = len(data_2)
print('Len data {}, len data2 {}'.format(len_data,len_data2))
# Out:
# Len data 71045, len data2 219932

# %%
data_3 = data_2[:len(data)]

# %%
ipd.Audio(data + delayed + data_3, rate=samplerate) # load a NumPy array
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
